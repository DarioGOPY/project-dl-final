# %% [markdown]
# # Retrieval-Augmented Generation (RAG)
#
# Implementar un modelo de RAG (QA o chat con documentos): colección de documentos (PDFs, páginas web, artículos). Puedes usar un dataset pequeño: SQuAD para QA o crear un conjunto de FAQs del dominio elegido.
#
# ### Lineamientos:
# - Usar el dataset SQuAD para implementar un RAG de preguntas y respuestas.
#
# ### Puntos Clave:
# - Unir el procesamiento de texto y embeddings. Usando el framework LangChain.
# - Crear una visualizacion del diagrama de flujo del pipeline RAG.
# - Guarda ejemplos de preguntas con contexto y respuestas, y marca si la respuesta es correcta.

# %%
# !pip install colab-xterm
# %load_ext colabxterm
